# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Fids = [0.899969482421875,0.7493103027343749,
        0.7962097167968749,0.6952026367187499,0.802203369140625,0.60069580078125,
        0.7023254394531249,0.792236328125,0.6551940917968749,0.8066650390625,
        0.751910400390625,0.8487365722656249,0.753082275390625,0.6478332519531249,0.7482666015624999,0.5970764160156249]

# %%
plt.semilogy(Fids,'-o')
plt.ylabel('Infidelity')
plt.xlabel('Evaluations')
plt.title('ibmq_armonk')
plt.savefig('experiment.png')
